# %%
import numpy as np
from matplotlib import pyplot as plt
import random
import scipy.linalg as spla

def dg(A):
    return A.conj().T

random.seed(1)

# %%
# Model parameters.
γ = 1
δ = 0
Ω = 0.5
dΩ = 0.001

# Initial state.
ψ0 = np.array([1, 0], dtype="complex128")

# Simulation parameters.
number_trajectories = 20
t_final = 100
dt = 0.01

# %%
# Operators.
σ = np.array([[0,1],[0,0]], dtype="complex128")
c = np.sqrt(γ) * σ
σz = np.array([[1,0], [0,-1]], dtype="complex128")

# Hamiltonian and jump operator.
H = - δ * dg(σ) @ σ + Ω/2. * (dg(σ) + σ)
M1 = np.sqrt(dt) * c

# Displaced operators to compute the derivatives.
Hp = - δ * dg(σ) @ σ + (Ω + dΩ)/2. * (dg(σ) + σ)
Hm = - δ * dg(σ) @ σ + (Ω - dΩ)/2. * (dg(σ) + σ)
M1p = M1
M1m = M1

# The jump operators have to be passed as a list.
M_l = [M1]
Mp_l = [M1p]
Mm_l = [M1m]

# %%
def gillespie_fisher(H, Hp, Hm, M_l, Mp_l, Mm_l, dθ, ψ0, t_final, dt, number_trajectories):
    print("Gillespie-Fisher method - Welcome")
    print("=> Starting the pre-computation stage")
    t_range = np.arange(0, t_final, dt)
    
    # Constructs the overall jump operator.
    J = np.zeros_like(M_l[0])
    for M in M_l:
        J += dg(M) @ M
    # Effective (non-Hermitian) Hamiltonian.
    He = H - 1j/2. * J
    
    # Constructs the no-jump evolution operators for all the relevant times.
    V = [] # List of the no-jump evolution operators.
    Qs = [] # List of the non-state-dependent part of the waiting time distribution.
    for t in t_range:
        ev_op = spla.expm(-1j * He * t)
        V.append(ev_op)
        nsd_wtd = dg(ev_op) @ J @ ev_op
        Qs.append(nsd_wtd)
    # Prints the matrix norm of the latest Qs.
    error = spla.norm(Qs[-1])
    print(f"-> Truncation error given by norm of latest Qs matrix -> {error}")
    
    # Displaced versions of the effective Hamiltonian.
    Jp = np.zeros_like(Mp_l[0])
    for Mp in Mp_l:
        Jp += dg(Mp) @ Mp
    Hep = Hp - 1j/2. * Jp
    Jm = np.zeros_like(Mm_l[0])
    for Mm in Mm_l:
        Jm += dg(Mm) @ Mm
    Hem = Hm - 1j/2. * Jm
    
    # Vector of the derivatives of the evolution operator wrt the parameter.
    Vdot = []
    for t in t_range:
        vd = (spla.expm(-1j * Hep * t) - spla.expm(-1j * Hem * t)) / (2. * dθ)
        Vdot.append(vd)
    # Derivatives of all the jump operators.
    Mdot = []
    for n_M in range(len(M_l)):
        Mdot.append((Mp_l[n_M] - Mm_l[n_M]) / (2 * dθ))
    # Precomputation of all the derivatives of MkV(t).
    Δ = []
    for n_M in range(len(M_l)):
        fixed_M = []
        for n_t, t in enumerate(t_range):
            obj = Mdot[n_M] @ V[n_t] + M[n_M] @ Vdot[n_t]
            fixed_M.append(obj)
        Δ.append(fixed_M)
    
    # Evolution cycle.
    print("=> Starting the evolution cycle.")
    
    # List for the results.
    trajectories_results = []
    
    # Cycle over the trajectories.
    for trajectory in range(number_trajectories):
        print(f"-> Starting trajectory {trajectory}")
        
        # Initial state.
        ψ = ψ0
        # Absolute time.
        τ = 0
        # Initial ξ matrix.
        ξ = np.zeros((2,2), dtype="complex128")
        
        results = []
        
        while τ < t_final:
            dict_jump = {}
            
            # Pass to density matrix formalism.
            ρ = np.outer(dg(ψ), ψ)
            
            # Compute the waiting time distribution, exploiting the pre-computed part.
            Ps = []
            for Q in Qs:
                # Even though the number is real, theree might be small imaginary noise.
                wtd = np.real(dg(ψ) @ Q @ ψ)
                Ps.append(wtd)
                
            # Sample from the waiting time distribution.
            n_T = random.choices(range(len(t_range)), weights=Ps)[0]
            # TODO: what happens if T brings us beyond t_final?

            # Increase the absolute time.
            τ += t_range[n_T]
            dict_jump["AbsTime"] = τ
            dict_jump["TimeSinceLast"] = t_range[n_T]

            # Update the state.
            ψ = V[n_T] @ ψ
            # Choose where to jump.
            weights = []
            for M in M_l:
                weight = np.real(dg(ψ) @ dg(M) @ M @ ψ)
                weights.append(weight)
            n_jump = random.choices(range(len(M_l)), weights=weights)[0]
            dict_jump["JumpChannel"] = n_jump
            # Update the state after the jump.
            ψ = M_l[n_jump] @ ψ
            norm = spla.norm(ψ)
            # Renormalize the state.
            ψ = ψ / norm

            print(dict_jump)
                        
            # Compute the ξ matrix.
            ξ = 1./(norm**2) * (M_l[n_jump] @ V[n_T] @ ξ @ dg(V[n_T]) @ dg(M_l[n_jump]))
            ξ += 1./(norm**2) * (Δ[n_jump][n_T] @ ρ @ dg(V[n_T]) @ dg(M_l[n_jump]))
            ξ += 1./(norm**2) * (M_l[n_jump] @ V[n_T] @ ρ @ dg(Δ[n_jump][n_T]))
            dict_jump["ξAfter"] = ξ
            dict_jump["ψAfter"] = ψ
            dict_jump["trξ2"] = (np.real(np.trace(ξ)))**2
        
            results.append(dict_jump)
                
        trajectories_results.append(results)

# %%
gillespie_fisher(H, Hp, Hm, M_l, Mp_l, Mm_l, dΩ, ψ0, t_final, dt, number_trajectories)
# Out:
# Gillespie-Fisher method - Welcome
# => Starting the pre-computation stage
# -> Truncation error given by norm of latest Qs matrix -> 0.00608198630567942
# => Starting the evolution cycle.
# -> Starting trajectory 0
# {'AbsTime': 53.07, 'TimeSinceLast': 53.07, 'JumpChannel': 0}
# {'AbsTime': 83.9, 'TimeSinceLast': 30.830000000000002, 'JumpChannel': 0}
# {'AbsTime': 92.31, 'TimeSinceLast': 8.41, 'JumpChannel': 0}
# {'AbsTime': 172.81, 'TimeSinceLast': 80.5, 'JumpChannel': 0}
# -> Starting trajectory 1
# {'AbsTime': 33.06, 'TimeSinceLast': 33.06, 'JumpChannel': 0}
# {'AbsTime': 52.19, 'TimeSinceLast': 19.13, 'JumpChannel': 0}
# {'AbsTime': 97.69999999999999, 'TimeSinceLast': 45.51, 'JumpChannel': 0}
# {'AbsTime': 155.67, 'TimeSinceLast': 57.97, 'JumpChannel': 0}
# -> Starting trajectory 2
# {'AbsTime': 65.09, 'TimeSinceLast': 65.09, 'JumpChannel': 0}
# {'AbsTime': 84.43, 'TimeSinceLast': 19.34, 'JumpChannel': 0}
# {'AbsTime': 127.39000000000001, 'TimeSinceLast': 42.96, 'JumpChannel': 0}
# -> Starting trajectory 3
# {'AbsTime': 33.74, 'TimeSinceLast': 33.74, 'JumpChannel': 0}
# {'AbsTime': 124.43, 'TimeSinceLast': 90.69, 'JumpChannel': 0}
# -> Starting trajectory 4
# {'AbsTime': 21.2, 'TimeSinceLast': 21.2, 'JumpChannel': 0}
# {'AbsTime': 26.24, 'TimeSinceLast': 5.04, 'JumpChannel': 0}
# {'AbsTime': 70.84, 'TimeSinceLast': 44.6, 'JumpChannel': 0}
# {'AbsTime': 85.67, 'TimeSinceLast': 14.83, 'JumpChannel': 0}
# {'AbsTime': 169.66, 'TimeSinceLast': 83.99, 'JumpChannel': 0}
# -> Starting trajectory 5
# {'AbsTime': 65.94, 'TimeSinceLast': 65.94, 'JumpChannel': 0}
# {'AbsTime': 97.55, 'TimeSinceLast': 31.61, 'JumpChannel': 0}
# {'AbsTime': 166.51, 'TimeSinceLast': 68.96000000000001, 'JumpChannel': 0}
# -> Starting trajectory 6
# {'AbsTime': 82.16, 'TimeSinceLast': 82.16, 'JumpChannel': 0}
# {'AbsTime': 177.0, 'TimeSinceLast': 94.84, 'JumpChannel': 0}
# -> Starting trajectory 7
# {'AbsTime': 16.35, 'TimeSinceLast': 16.35, 'JumpChannel': 0}
# {'AbsTime': 34.78, 'TimeSinceLast': 18.43, 'JumpChannel': 0}
# {'AbsTime': 104.96000000000001, 'TimeSinceLast': 70.18, 'JumpChannel': 0}
# -> Starting trajectory 8
# {'AbsTime': 61.56, 'TimeSinceLast': 61.56, 'JumpChannel': 0}
# {'AbsTime': 92.06, 'TimeSinceLast': 30.5, 'JumpChannel': 0}
# {'AbsTime': 107.52000000000001, 'TimeSinceLast': 15.46, 'JumpChannel': 0}
# -> Starting trajectory 9
# {'AbsTime': 4.7, 'TimeSinceLast': 4.7, 'JumpChannel': 0}
# {'AbsTime': 83.58, 'TimeSinceLast': 78.88, 'JumpChannel': 0}
# {'AbsTime': 104.32, 'TimeSinceLast': 20.740000000000002, 'JumpChannel': 0}
# -> Starting trajectory 10
# {'AbsTime': 94.8, 'TimeSinceLast': 94.8, 'JumpChannel': 0}
# {'AbsTime': 166.2, 'TimeSinceLast': 71.4, 'JumpChannel': 0}
# -> Starting trajectory 11
# {'AbsTime': 58.67, 'TimeSinceLast': 58.67, 'JumpChannel': 0}
# {'AbsTime': 99.35, 'TimeSinceLast': 40.68, 'JumpChannel': 0}
# {'AbsTime': 194.94, 'TimeSinceLast': 95.59, 'JumpChannel': 0}
# -> Starting trajectory 12
# {'AbsTime': 78.28, 'TimeSinceLast': 78.28, 'JumpChannel': 0}
# {'AbsTime': 93.73, 'TimeSinceLast': 15.450000000000001, 'JumpChannel': 0}
# {'AbsTime': 102.21000000000001, 'TimeSinceLast': 8.48, 'JumpChannel': 0}
# -> Starting trajectory 13
# {'AbsTime': 94.8, 'TimeSinceLast': 94.8, 'JumpChannel': 0}
# {'AbsTime': 150.15, 'TimeSinceLast': 55.35, 'JumpChannel': 0}
# -> Starting trajectory 14
# {'AbsTime': 8.040000000000001, 'TimeSinceLast': 8.040000000000001, 'JumpChannel': 0}
# {'AbsTime': 27.82, 'TimeSinceLast': 19.78, 'JumpChannel': 0}
# {'AbsTime': 29.82, 'TimeSinceLast': 2.0, 'JumpChannel': 0}
# {'AbsTime': 69.64, 'TimeSinceLast': 39.82, 'JumpChannel': 0}
# {'AbsTime': 126.43, 'TimeSinceLast': 56.79, 'JumpChannel': 0}
# -> Starting trajectory 15
# {'AbsTime': 80.9, 'TimeSinceLast': 80.9, 'JumpChannel': 0}
# {'AbsTime': 102.79, 'TimeSinceLast': 21.89, 'JumpChannel': 0}
# -> Starting trajectory 16
# {'AbsTime': 21.07, 'TimeSinceLast': 21.07, 'JumpChannel': 0}
# {'AbsTime': 40.97, 'TimeSinceLast': 19.900000000000002, 'JumpChannel': 0}
# {'AbsTime': 114.12, 'TimeSinceLast': 73.15, 'JumpChannel': 0}
# -> Starting trajectory 17
# {'AbsTime': 95.77, 'TimeSinceLast': 95.77, 'JumpChannel': 0}
# {'AbsTime': 139.34, 'TimeSinceLast': 43.57, 'JumpChannel': 0}
# -> Starting trajectory 18
# {'AbsTime': 70.9, 'TimeSinceLast': 70.9, 'JumpChannel': 0}
# {'AbsTime': 103.05000000000001, 'TimeSinceLast': 32.15, 'JumpChannel': 0}
# -> Starting trajectory 19
# {'AbsTime': 7.57, 'TimeSinceLast': 7.57, 'JumpChannel': 0}
# {'AbsTime': 15.610000000000001, 'TimeSinceLast': 8.040000000000001, 'JumpChannel': 0}
# {'AbsTime': 62.22, 'TimeSinceLast': 46.61, 'JumpChannel': 0}
# {'AbsTime': 132.6, 'TimeSinceLast': 70.38, 'JumpChannel': 0}
